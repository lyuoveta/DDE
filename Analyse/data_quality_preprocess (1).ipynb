# %%
# !pip install faker >> None

# %%
# !pip install typing_extensions==4.7.1 --upgrade >> None

# %%
# !pip install -U pandas-profiling >> None
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyldavis 3.4.1 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# ydata-profiling 4.6.4 requires visions[type_image_path]==0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
# !pip install ydata_profiling >> None
# Out:
# WARNING: visions 0.7.5 does not provide the extra 'type-image-path'
# WARNING: Error parsing requirements for click: [Errno 2] No such file or directory: '/Users/amkorneeva/opt/anaconda3/lib/python3.9/site-packages/click-8.1.3.dist-info/METADATA'
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install fasteda >> None

# %%
# !pip install rdkit >> None

# %%
# !pip install ipywidgets >> None

# %%
import pandas as pd
data = pd.read_csv(r'D:\Downloads\combined_data (1).csv')
cleaned_data = pd.read_csv(r'D:\Downloads\cleaned_data.csv')

# %%
data['dates'] = pd.to_datetime(data['dates'])
data.loc[:,'age'] = pd.to_numeric(data['age'], errors='coerce')
data.loc[:,'duration, months'] = pd.to_numeric(data['duration, months'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1253 non-null   int64
#  1   dates             1253 non-null   datetime64[ns]
#  2   name              1253 non-null   object
#  3   age               0 non-null      object
#  4   duration, months  0 non-null      object
#  5   сondition         1181 non-null   object
#  6   overall rating    1253 non-null   float64
#  7   reviews           1080 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 78.4+ KB

# %%
from ydata_profiling import ProfileReport
# from .autonotebook import tqdm as notebook_tqdm

profile = ProfileReport(data, title="Profiling Report")

# %%
import ipywidgets

profile.to_file("original.html")
# Out:
# C:\Users\lyuob\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\lyuob\anaconda3\Lib\site-packages\ydata_profiling\model\typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# C:\Users\lyuob\anaconda3\Lib\site-packages\ydata_profiling\model\typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# ...

# %%
cleaned_data['dates'] = pd.to_datetime(cleaned_data['dates'])

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1080 non-null   int64
#  1   dates             1080 non-null   datetime64[ns]
#  2   name              1080 non-null   object
#  3   age               1080 non-null   int64
#  4   duration, months  1080 non-null   int64
#  5   сondition         1080 non-null   object
#  6   overall rating    1080 non-null   float64
#  7   reviews           1080 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 67.6+ KB

# %%
profile_clean = ProfileReport(cleaned_data, title="Profiling Report")

# %%
comparison_report = profile.compare(profile_clean)
comparison_report.to_file("original_vs_transformed.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\lyuob\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Ginkgo'')
#   warnings.warn(
# C:\Users\lyuob\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
comparison_report
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v[&#x27;v4.6.4&#x27;, &#x27;v4.6.4&#x27;]&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;[datetime.datetime(2024, 1, 18, 17, 2, 2, 634589), datetime.datetime(2024, 1, 18, 17, 4, 56, 84310)]&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
